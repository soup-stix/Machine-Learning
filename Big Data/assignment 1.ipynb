# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split    
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow 
import keras
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\arul_\Desktop\Anand\6th sem college\ML\Big Data\assignment 1.ipynb Cell 1 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/arul_/Desktop/Anand/6th%20sem%20college/ML/Big%20Data/assignment%201.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/arul_/Desktop/Anand/6th%20sem%20college/ML/Big%20Data/assignment%201.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> import seaborn as sns
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arul_/Desktop/Anand/6th%20sem%20college/ML/Big%20Data/assignment%201.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> import tensorflow
#       <a href='vscode-notebook-cell:/c%3A/Users/arul_/Desktop/Anand/6th%20sem%20college/ML/Big%20Data/assignment%201.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> import keras
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py:37, in <module>
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\__init__.py:37, in <module>
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#      42 from tensorflow.python import data
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\context.py:29, in <module>
#      26 import numpy as np
#      27 import six
# ---> 29 from tensorflow.core.framework import function_pb2
#      30 from tensorflow.core.protobuf import config_pb2
#      31 from tensorflow.core.protobuf import coordination_config_pb2
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\function_pb2.py:16, in <module>
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\attr_value_pb2.py:16, in <module>
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:16, in <module>
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:16, in <module>
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      20 DESCRIPTOR = _descriptor.FileDescriptor(
#      21   name='tensorflow/core/framework/resource_handle.proto',
#      22   package='tensorflow',
#    (...)
#      26   ,
#      27   dependencies=[tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2.DESCRIPTOR,tensorflow_dot_core_dot_framework_dot_types__pb2.DESCRIPTOR,])
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:36, in <module>
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='tensorflow/core/framework/tensor_shape.proto',
#      20   package='tensorflow',
#    (...)
#      23   serialized_pb=_b('\n,tensorflow/core/framework/tensor_shape.proto\x12\ntensorflow\"z\n\x10TensorShapeProto\x12-\n\x03\x64im\x18\x02 \x03(\x0b\x32 .tensorflow.TensorShapeProto.Dim\x12\x14\n\x0cunknown_rank\x18\x03 \x01(\x08\x1a!\n\x03\x44im\x12\x0c\n\x04size\x18\x01 \x01(\x03\x12\x0c\n\x04name\x18\x02 \x01(\tB\x87\x01\n\x18org.tensorflow.frameworkB\x11TensorShapeProtosP\x01ZSgithub.com/tensorflow/tensorflow/tensorflow/go/core/framework/tensor_shape_go_proto\xf8\x01\x01\x62\x06proto3')
#      24 )
#      29 _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
#      30   name='Dim',
#      31   full_name='tensorflow.TensorShapeProto.Dim',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='size', full_name='tensorflow.TensorShapeProto.Dim.size', index=0,
#      38       number=1, type=3, cpp_type=2, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#      45       number=2, type=9, cpp_type=9, label=1,
#      46       has_default_value=False, default_value=_b("").decode('utf-8'),
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50   ],
#      51   extensions=[
#      52   ],
#      53   nested_types=[],
#      54   enum_types=[
#      55   ],
#      56   serialized_options=None,
#      57   is_extendable=False,
#      58   syntax='proto3',
#      59   extension_ranges=[],
#      60   oneofs=[
#      61   ],
#      62   serialized_start=149,
#      63   serialized_end=182,
#      64 )
#      66 _TENSORSHAPEPROTO = _descriptor.Descriptor(
#      67   name='TensorShapeProto',
#      68   full_name='tensorflow.TensorShapeProto',
#    (...)
#     100   serialized_end=182,
#     101 )
#     103 _TENSORSHAPEPROTO_DIM.containing_type = _TENSORSHAPEPROTO
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\descriptor.py:560, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     554 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     555             default_value, message_type, enum_type, containing_type,
#     556             is_extension, extension_scope, options=None,
#     557             serialized_options=None,
#     558             has_default_value=True, containing_oneof=None, json_name=None,
#     559             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 560   _message.Message._CheckCalledFromGeneratedFile()
#     561   if is_extension:
#     562     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
ipl = pd.read_csv("./ipl dataset.csv")
ipl.head()
# Out:
#    Unnamed: 0  match_id                  venue  innings  ball  \
# 0           0    335982  M Chinnaswamy Stadium        1   0.1
# 1           1    335982  M Chinnaswamy Stadium        1   0.2
# 2           2    335982  M Chinnaswamy Stadium        1   0.3
# 3           3    335982  M Chinnaswamy Stadium        1   0.4
# 4           4    335982  M Chinnaswamy Stadium        1   0.5
#
#             batting_team                 bowling_team      striker  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
#
#    non_striker   bowler  runs_off_bat  extras wicket_type player_dismissed  \
# 0  BB McCullum  P Kumar           0.0     1.0
# 1   SC Ganguly  P Kumar           0.0     0.0
# 2   SC Ganguly  P Kumar           0.0     1.0
# 3   SC Ganguly  P Kumar           0.0     0.0
# 4   SC Ganguly  P Kumar           0.0     0.0
#
#    run  wickets  truns     y
# 0  1.0      0.0    1.0  68.0
# 1  0.0      0.0    1.0  68.0
# 2  1.0      0.0    2.0  68.0
# 3  0.0      0.0    2.0  68.0
# 4  0.0      0.0    2.0  68.0

# %%
str_cols = ipl.columns[ipl.dtypes==object]
ipl[str_cols] = ipl[str_cols].fillna('.')

# %%
a1 = ipl['venue'].unique()
a2 = ipl['batting_team'].unique()
a3 = ipl['bowling_team'].unique()
a4 = ipl['striker'].unique()
a5 = ipl['bowler'].unique()
  
def labelEncoding(data):
    dataset = pd.DataFrame(ipl)
    feature_dict ={}
      
    for feature in dataset:
        if dataset[feature].dtype==object:
            le = preprocessing.LabelEncoder()
            fs = dataset[feature].unique()
            le.fit(fs)
            dataset[feature] = le.transform(dataset[feature])
            feature_dict[feature] = le
              
    return dataset
  
labelEncoding(ipl)
ipl.drop(["Unnamed: 0"],axis=1)
# Out:
#        match_id  venue  innings  ball  batting_team  bowling_team  striker  \
# 0        335982     15        1   0.1             7            13      186
# 1        335982     15        1   0.2             7            13       30
# 2        335982     15        1   0.3             7            13       30
# 3        335982     15        1   0.4             7            13       30
# 4        335982     15        1   0.5             7            13       30
# ...         ...    ...      ...   ...           ...           ...      ...
# 32173   1178420     31        1   6.2            14            10       48
# 32174   1178420     31        1   6.3            14            10      127
# 32175   1178420     31        1   6.4            14            10       48
# 32176   1178420     31        1   6.5            14            10      127
# 32177   1178420     31        1   6.6            14            10       48
#
#        non_striker  bowler  runs_off_bat  extras  wicket_type  \
# 0               30     201           0.0     1.0            0
# 1              184     201           0.0     0.0            0
# 2              184     201           0.0     1.0            0
# 3              184     201           0.0     0.0            0
# 4              184     201           0.0     0.0            0
# ...            ...     ...           ...     ...          ...
# 32173          126     220           1.0     0.0            0
# 32174           47     220           1.0     0.0            0
# 32175          126     220           1.0     0.0            0
# 32176           47     220           1.0     0.0            0
# 32177          126     220           1.0     0.0            0
#
#        player_dismissed  run  wickets  truns     y
# 0                     0  1.0      0.0    1.0  68.0
# 1                     0  0.0      0.0    1.0  68.0
# 2                     0  1.0      0.0    2.0  68.0
# 3                     0  0.0      0.0    2.0  68.0
# 4                     0  0.0      0.0    2.0  68.0
# ...                 ...  ...      ...    ...   ...
# 32173                 0  1.0      1.0   53.0  57.0
# 32174                 0  1.0      1.0   54.0  57.0
# 32175                 0  1.0      1.0   55.0  57.0
# 32176                 0  1.0      1.0   56.0  57.0
# 32177                 0  1.0      1.0   57.0  57.0
#
# [32178 rows x 17 columns]

# %%
ip_dataset = ipl[['venue','innings', 'batting_team', 
                      'bowling_team', 'striker', 'non_striker',
                      'bowler']]
  
b1 = ip_dataset['venue'].unique()
b2 = ip_dataset['batting_team'].unique()
b3 = ip_dataset['bowling_team'].unique()
b4 = ip_dataset['striker'].unique()
b5 = ip_dataset['bowler'].unique()
ipl.fillna(0,inplace=True)
  
features={}
  
for i in range(len(a1)):
    features[a1[i]]=b1[i]
for i in range(len(a2)):
    features[a2[i]]=b2[i]
for i in range(len(a3)):
    features[a3[i]]=b3[i]
for i in range(len(a4)):
    features[a4[i]]=b4[i]
for i in range(len(a5)):
    features[a5[i]]=b5[i]
      
features
# Out:
# {'M Chinnaswamy Stadium': 15,
#  'Punjab Cricket Association Stadium, Mohali': 26,
#  'Feroz Shah Kotla': 9,
#  'Eden Gardens': 8,
#  'Wankhede Stadium': 39,
#  'Sawai Mansingh Stadium': 31,
#  'Rajiv Gandhi International Stadium, Uppal': 28,
#  'MA Chidambaram Stadium, Chepauk': 18,
#  'Dr DY Patil Sports Academy': 5,
#  'Newlands': 22,
#  "St George's Park": 35,
#  'Kingsmead': 14,
#  'SuperSport Park': 37,
#  'Buffalo Park': 3,
#  'New Wanderers Stadium': 21,
#  'De Beers Diamond Oval': 4,
#  'OUTsurance Oval': 23,
#  'Brabourne Stadium': 2,
#  'Sardar Patel Stadium, Motera': 29,
#  'Barabati Stadium': 1,
#  'Vidarbha Cricket Association Stadium, Jamtha': 38,
#  'Himachal Pradesh Cricket Association Stadium': 11,
#  'Nehru Stadium': 20,
#  'Holkar Cricket Stadium': 12,
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium': 6,
#  'Subrata Roy Sahara Stadium': 36,
#  'Shaheed Veer Narayan Singh International Stadium': 32,
#  'JSCA International Stadium Complex': 13,
#  'Sheikh Zayed Stadium': 34,
#  'Sharjah Cricket Stadium': 33,
#  'Dubai International Cricket Stadium': 7,
#  'Maharashtra Cricket Association Stadium': 19,
#  'Punjab Cricket Association IS Bindra Stadium, Mohali': 25,
#  'Saurashtra Cricket Association Stadium': 30,
#  'Green Park': 10,
#  'M.Chinnaswamy Stadium': 16,
#  'MA Chidambaram Stadium': 17,
#  'Arun Jaitley Stadium': 0,
#  'Rajiv Gandhi International Stadium': 27,
#  'Punjab Cricket Association IS Bindra Stadium': 24,
#  'Kolkata Knight Riders': 7,
#  'Chennai Super Kings': 0,
#  'Rajasthan Royals': 10,
#  'Deccan Chargers': 1,
#  'Mumbai Indians': 8,
#  'Kings XI Punjab': 5,
#  'Royal Challengers Bangalore': 13,
#  'Delhi Daredevils': 3,
#  'Kochi Tuskers Kerala': 6,
#  'Pune Warriors': 9,
#  'Sunrisers Hyderabad': 14,
#  'Rising Pune Supergiants': 12,
#  'Gujarat Lions': 4,
#  'Rising Pune Supergiant': 11,
#  'Delhi Capitals': 2,
#  'SC Ganguly': 259,
#  'BB McCullum': 30,
#  'RT Ponting': 174,
#  'PA Patel': 150,
#  'ML Hayden': 129,
#  'MEK Hussey': 123,
#  'MS Dhoni': 135,
#  'T Kohli': 213,
#  'YK Pathan': 314,
#  'SR Watson': 275,
#  'M Kaif': 113,
#  'AC Gilchrist': 9,
#  'Y Venugopal Rao': 312,
#  'VVS Laxman': 224,
#  'A Symonds': 8,
#  'L Ronchi': 108,
#  'ST Jayasuriya': 203,
#  'DJ Thornely': 56,
#  'RV Uthappa': 175,
#  'PR Shah': 156,
#  'K Goel': 131,
#  'JR Hopes': 127,
#  'KC Sangakkara': 98,
#  'DPMD Jayawardene': 59,
#  'SK Raina': 264,
#  'Shahid Afridi': 281,
#  'IK Pathan': 102,
#  'WP Saha': 228,
#  'DJ Hussey': 73,
#  'S Chanderpaul': 178,
#  'R Dravid': 160,
#  'LRPL Taylor': 112,
#  'JH Kallis': 119,
#  'V Kohli': 300,
#  'AM Rahane': 18,
#  'SM Pollock': 271,
#  'G Gambhir': 68,
#  'V Sehwag': 302,
#  'S Dhawan': 243,
#  'Shoaib Malik': 210,
#  'MK Tiwary': 128,
#  'DB Das': 49,
#  'GC Smith': 69,
#  'SA Asnodkar': 183,
#  'HH Gibbs': 74,
#  'SP Fleming': 194,
#  'S Vidyut': 182,
#  'SE Marsh': 188,
#  'Yuvraj Singh': 316,
#  'B Chipli': 28,
#  'W Jaffer': 226,
#  'S Badrinath': 177,
#  'YV Takawale': 232,
#  'CL White': 45,
#  'S Anirudha': 176,
#  'AB de Villiers': 7,
#  'A Chopra': 0,
#  'BJ Hodge': 51,
#  'Salman Butt': 207,
#  'J Arunkumar': 81,
#  'Misbah-ul-Haq': 139,
#  'Mohammad Hafeez': 186,
#  'SR Tendulkar': 199,
#  'SP Goswami': 195,
#  'LA Pomersbach': 109,
#  'SB Styris': 257,
#  'MV Boucher': 137,
#  'JD Ryder': 113,
#  'KP Pietersen': 147,
#  'RS Bopara': 236,
#  'CH Gayle': 56,
#  'TM Dilshan': 296,
#  'PC Valthaty': 152,
#  'RJ Quiney': 169,
#  'DR Smith': 82,
#  'KD Karthik': 99,
#  'AA Bilakhia': 4,
#  'RG Sharma': 229,
#  'Harbhajan Singh': 98,
#  'AM Nayar': 27,
#  'R Bishnoi': 159,
#  'M Vijay': 168,
#  'JP Duminy': 125,
#  'DJ Bravo': 70,
#  'NV Ojha': 146,
#  'MN van Wyk': 132,
#  'TL Suman': 295,
#  'Yashpal Singh': 233,
#  'S Sohal': 181,
#  'SM Katich': 191,
#  'AN Ghosh': 19,
#  'DA Warner': 48,
#  'GJ Bailey': 71,
#  'M Manhas': 115,
#  'Niraj Patel': 147,
#  'J Botha': 106,
#  'MK Pandey': 127,
#  'RE van der Merwe': 227,
#  'Mohammad Ashraful': 140,
#  'CA Pujara': 41,
#  'OA Shah': 148,
#  'AD Mathews': 20,
#  'MS Bisla': 134,
#  'AP Tare': 21,
#  'SS Tiwary': 202,
#  'AT Rayudu': 24,
#  'EJG Morgan': 64,
#  'AA Jhunjhunwala': 12,
#  'MJ Lumb': 126,
#  'DR Martyn': 60,
#  'FY Fazal': 67,
#  'MD Mishra': 121,
#  'Mandeep Singh': 138,
#  'PD Collingwood': 153,
#  'KM Jadhav': 104,
#  'C Madan': 36,
#  'AG Paunikar': 14,
#  'R McLaren': 218,
#  'Anirudh Singh': 25,
#  'IR Jaggi': 79,
#  'Sunny Singh': 212,
#  'UBT Chand': 218,
#  'AJ Finch': 24,
#  'MA Agarwal': 118,
#  'RA Jadeja': 226,
#  'AL Menaria': 26,
#  'DJ Jacobs': 55,
#  'AS Raut': 23,
#  'TD Paine': 214,
#  'BJ Haddin': 33,
#  'R Sathish': 162,
#  'MS Wade': 136,
#  'Y Nagar': 311,
#  'AC Blizzard': 8,
#  'M Klinger': 114,
#  'DB Ravi Teja': 50,
#  'CJ Ferguson': 44,
#  'CA Ingram': 39,
#  'RN ten Doeschate': 170,
#  'F du Plessis': 66,
#  'LR Shukla': 160,
#  'R Bhatia': 216,
#  'WD Parnell': 308,
#  'AB McDonald': 16,
#  'MN Samuels': 181,
#  'DT Christian': 84,
#  'RE Levi': 166,
#  'N Saini': 143,
#  'JEC Franklin': 118,
#  'DJ Harris': 71,
#  'MJ Clarke': 175,
#  'AP Majumdar': 20,
#  'STR Binny': 278,
#  'SD Chitnis': 261,
#  'Azhar Mahmood': 38,
#  'PA Reddy': 151,
#  'MC Juneja': 120,
#  'MDKJ Perera': 122,
#  'KK Nair': 102,
#  'M Vohra': 117,
#  'Gurkeerat Singh': 94,
#  'Q de Kock': 157,
#  'GH Vihari': 90,
#  'BB Samantray': 31,
#  'KV Sharma': 149,
#  'A Mishra': 4,
#  'NLTC Perera': 196,
#  'DJG Sammy': 76,
#  'A Mukund': 2,
#  'JP Faulkner': 126,
#  'SV Samson': 205,
#  'CM Gautam': 46,
#  'MC Henriques': 171,
#  'GJ Maxwell': 91,
#  'CA Lynn': 40,
#  'CJ Anderson': 58,
#  'S Rana': 180,
#  'JA Morkel': 111,
#  'KL Rahul': 103,
#  'BR Dunk': 35,
#  'DA Miller': 47,
#  'LMP Simmons': 110,
#  'VH Zol': 223,
#  'Ankit Sharma': 35,
#  'KK Cooper': 143,
#  'RR Rossouw': 172,
#  'SS Iyer': 201,
#  'SPD Smith': 198,
#  'AD Russell': 21,
#  'AR Patel': 31,
#  'KA Pollard': 137,
#  'HH Pandya': 96,
#  'JC Buttler': 85,
#  'P Negi': 202,
#  'DJ Hooda': 72,
#  'MJ Guptill': 125,
#  'SW Billings': 206,
#  'KS Williamson': 148,
#  'MP Stoinis': 182,
#  'RR Pant': 171,
#  'UT Khawaja': 219,
#  'HM Amla': 76,
#  'SA Yadav': 254,
#  'Shakib Al Hasan': 282,
#  'N Rana': 192,
#  'KH Pandya': 140,
#  'PP Chawla': 210,
#  'C Munro': 37,
#  'ER Dwivedi': 65,
#  'JJ Roy': 89,
#  'Vishnu Vinod': 225,
#  'RA Tripathi': 165,
#  'BA Stokes': 46,
#  'SP Narine': 274,
#  'TM Head': 217,
#  'Ishan Kishan': 80,
#  'SP Jackson': 196,
#  'R Tewatia': 224,
#  'C de Grandhomme': 55,
#  'MM Ali': 178,
#  'JM Bairstow': 91,
#  'PP Shaw': 155,
#  'NS Naik': 145,
#  'SM Curran': 269,
#  'SN Khan': 193,
#  'V Shankar': 222,
#  'Shubman Gill': 211,
#  'JL Denly': 90,
#  'E Lewis': 63,
#  'DJM Short': 58,
#  'AD Hales': 10,
#  'K Gowtham': 132,
#  'JC Archer': 112,
#  'BCJ Cutting': 49,
#  'AD Nath': 12,
#  'P Kumar': 201,
#  'Z Khan': 317,
#  'AA Noffke': 13,
#  'B Lee': 43,
#  'S Sreesanth': 251,
#  'GD McGrath': 89,
#  'B Geeves': 40,
#  'MF Maharoof': 172,
#  'AB Dinda': 15,
#  'I Sharma': 100,
#  'AB Agarkar': 14,
#  'M Kartik': 162,
#  'R Vinay Kumar': 225,
#  'MM Patel': 179,
#  'SK Trivedi': 265,
#  'SK Warne': 266,
#  'Mohammad Asif': 185,
#  'A Nehra': 6,
#  'DS Kulkarni': 83,
#  'Pankaj Singh': 213,
#  'JDP Oram': 115,
#  'MS Gony': 184,
#  'P Amarnath': 199,
#  'M Muralitharan': 165,
#  'Sohail Tanvir': 286,
#  'RP Singh': 232,
#  'DNT Zoysa': 79,
#  'SB Bangar': 255,
#  'VRV Singh': 304,
#  'DW Steyn': 85,
#  'CRD Fernando': 64,
#  'Umar Gul': 299,
#  'VY Mahesh': 307,
#  'PJ Sangwan': 208,
#  'DP Vijaykumar': 81,
#  'Gagandeep Singh': 93,
#  'A Kumble': 3,
#  'WPUJC Vaas': 309,
#  'AD Mascarenhas': 19,
#  'PM Sarvesh Kumar': 209,
#  'RR Powar': 234,
#  'M Ntini': 166,
#  'VS Yeligati': 306,
#  'BAW Mendis': 47,
#  'Kamran Khan': 151,
#  'T Thushara': 291,
#  'A Flintoff': 2,
#  'DP Nannes': 80,
#  'AM Salvi': 28,
#  'DL Vettori': 78,
#  'FH Edwards': 86,
#  'Harmeet Singh': 99,
#  'PP Ojha': 211,
#  'L Balaji': 155,
#  'Joginder Sharma': 130,
#  'Anureet Singh': 36,
#  'RR Bose': 233,
#  'YA Abdulla': 313,
#  'SL Malinga': 267,
#  'VS Malik': 305,
#  'SM Harwood': 270,
#  'D du Preez': 67,
#  'RJ Harris': 230,
#  'Shoaib Ahmed': 285,
#  'A Singh': 7,
#  'M Morkel': 164,
#  'LA Carseldine': 157,
#  'S Tyagi': 252,
#  'A Mithun': 5,
#  'RR Raje': 235,
#  'B Akhil': 39,
#  'CK Langeveldt': 61,
#  'Jaskaran Singh': 129,
#  'SW Tait': 279,
#  'A Uniyal': 9,
#  'R Ashwin': 215,
#  'SE Bond': 262,
#  'S Ladda': 247,
#  'JM Kemp': 122,
#  'SJ Srivastava': 263,
#  'Bipul Sharma': 54,
#  'J Theron': 109,
#  'S Narwal': 250,
#  'KAJ Roach': 138,
#  'SB Jakati': 256,
#  'AC Voges': 18,
#  'SB Wagh': 258,
#  'AN Ahmed': 29,
#  'AP Dole': 30,
#  'MR Marsh': 183,
#  'L Ablish': 154,
#  'DE Bollinger': 69,
#  'UT Yadav': 298,
#  'JD Unadkat': 114,
#  'Iqbal Abdulla': 105,
#  'AC Thomas': 17,
#  'AG Murtaza': 23,
#  'JJ van der Wath': 121,
#  'S Aravind': 241,
#  'RV Gomez': 237,
#  'R Ninan': 219,
#  'J Syed Mohammad': 108,
#  'NL McCullum': 195,
#  'JE Taylor': 117,
#  'R Sharma': 222,
#  'KMDN Kulasekara': 145,
#  'TG Southee': 293,
#  'BA Bhatt': 45,
#  'P Parameswaran': 203,
#  'S Nadeem': 249,
#  'B Kumar': 41,
#  'VR Aaron': 303,
#  'AA Chavan': 11,
#  'SS Mundhe': 277,
#  'RW Price': 238,
#  'DAJ Bracewell': 68,
#  'HV Patel': 97,
#  'GB Hogg': 87,
#  'P Awana': 200,
#  'A Chandila': 0,
#  'RJ Peterson': 231,
#  'CJ McKay': 60,
#  'R Shukla': 223,
#  'KP Appanna': 146,
#  'V Pratap Singh': 301,
#  'BW Hilfenhaus': 52,
#  'K Upadhyay': 136,
#  'Sunny Gupta': 287,
#  'MG Johnson': 173,
#  'JJ Bumrah': 120,
#  'AS Rajpoot': 33,
#  'Mohammed Shami': 188,
#  'CH Morris': 57,
#  'Anand Rajan': 34,
#  'MM Sharma': 180,
#  'SMSM Senanayake': 272,
#  'R Rampaul': 221,
#  'R Dhawan': 217,
#  'JO Holder': 123,
#  'IC Pandey': 101,
#  'KW Richardson': 150,
#  'MG Neser': 174,
#  'PV Tambe': 212,
#  'Parvez Rasool': 214,
#  'S Kaul': 245,
#  'Sandeep Sharma': 280,
#  'NM Coulter-Nile': 197,
#  'MA Starc': 170,
#  'JDS Neesham': 116,
#  'YS Chahal': 315,
#  'S Badree': 242,
#  'Shivam Sharma': 284,
#  'Imran Tahir': 104,
#  'BE Hendricks': 50,
#  'PJ Cummins': 207,
#  'K Santokie': 135,
#  'S Gopal': 244,
#  'Karanveer Singh': 152,
#  'D Wiese': 66,
#  'MJ McClenaghan': 176,
#  'DJ Muthuswami': 74,
#  'SA Abbott': 253,
#  'TA Boult': 292,
#  'P Suyal': 206,
#  'RG More': 228,
#  'GS Sandhu': 92,
#  'J Suchith': 107,
#  'M de Lange': 169,
#  'J Yadav': 110,
#  'JW Hastings': 128,
#  'Mustafizur Rahman': 191,
#  'CR Brathwaite': 62,
#  'KJ Abbott': 141,
#  'P Sahu': 205,
#  'BB Sran': 48,
#  'T Shamsi': 290,
#  'Swapnil Singh': 288,
#  'SM Boland': 268,
#  'CJ Jordan': 59,
#  'S Kaushik': 246,
#  'DL Chahar': 77,
#  'KC Cariappa': 139,
#  'TS Mills': 297,
#  'A Choudhary': 1,
#  'CR Woakes': 63,
#  'Kuldeep Yadav': 153,
#  'T Natarajan': 289,
#  'Rashid Khan': 239,
#  'Basil Thampi': 53,
#  'AJ Tye': 25,
#  'AF Milne': 22,
#  'K Rabada': 134,
#  'Washington Sundar': 310,
#  'SN Thakur': 273,
#  'SS Agarwal': 276,
#  'NB Singh': 194,
#  'Mohammad Nabi': 187,
#  'Mohammed Siraj': 189,
#  'A Zampa': 10,
#  'LH Ferguson': 159,
#  'M Prasidh Krishna': 167,
#  'Rasikh Salam': 240,
#  'CV Varun': 65,
#  'GC Viljoen': 88,
#  'NA Saini': 193,
#  'M Ashwin': 161,
#  'S Lamichhane': 248,
#  'P Ray Barman': 204,
#  'Avesh Khan': 37,
#  'Mujeeb Ur Rahman': 190,
#  'SC Kuggeleijn': 260,
#  'JP Behrendorff': 124,
#  'AS Joseph': 32,
#  'MJ Santner': 177,
#  'KMA Paul': 144,
#  'KK Ahmed': 142,
#  'IS Sodhi': 103,
#  'B Stanlake': 44,
#  'K Khejroliya': 133,
#  'Shivam Mavi': 283,
#  'B Laughlin': 42,
#  'LE Plunkett': 158,
#  'M Markande': 163,
#  'DJ Willey': 75,
#  'L Ngidi': 156,
#  'TK Curran': 294,
#  'HF Gurney': 95,
#  'R Parag': 220,
#  'O Thomas': 198}

# %%
X = ipl[['venue', 'innings','batting_team',
             'bowling_team', 'striker','bowler']].values
y = ipl['y'].values
  
from sklearn.model_selection import train_test_split
  
X_train, X_test, y_train, y_test = train_test_split(
  X, y, test_size=0.33, random_state=42)

# %%
X = ipl[['venue', 'innings','batting_team',
             'bowling_team', 'striker','bowler']].values
y = ipl['y'].values
  
from sklearn.model_selection import train_test_split
  
X_train, X_test, y_train, y_test = train_test_split(
  X, y, test_size=0.33, random_state=42)

# %%
# from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\arul_\Desktop\Anand\6th sem college\ML\Big Data\assignment 1.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/arul_/Desktop/Anand/6th%20sem%20college/ML/Big%20Data/assignment%201.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # from keras.models import Sequential
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arul_/Desktop/Anand/6th%20sem%20college/ML/Big%20Data/assignment%201.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> from keras.layers import Dense,Dropout
#       <a href='vscode-notebook-cell:/c%3A/Users/arul_/Desktop/Anand/6th%20sem%20college/ML/Big%20Data/assignment%201.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> from keras.callbacks import EarlyStopping
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\__init__.py:21, in <module>
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python import tf2
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py:37, in <module>
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\__init__.py:37, in <module>
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#      42 from tensorflow.python import data
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\context.py:29, in <module>
#      26 import numpy as np
#      27 import six
# ---> 29 from tensorflow.core.framework import function_pb2
#      30 from tensorflow.core.protobuf import config_pb2
#      31 from tensorflow.core.protobuf import coordination_config_pb2
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\function_pb2.py:16, in <module>
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\attr_value_pb2.py:16, in <module>
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:16, in <module>
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:16, in <module>
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      20 DESCRIPTOR = _descriptor.FileDescriptor(
#      21   name='tensorflow/core/framework/resource_handle.proto',
#      22   package='tensorflow',
#    (...)
#      26   ,
#      27   dependencies=[tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2.DESCRIPTOR,tensorflow_dot_core_dot_framework_dot_types__pb2.DESCRIPTOR,])
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:36, in <module>
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='tensorflow/core/framework/tensor_shape.proto',
#      20   package='tensorflow',
#    (...)
#      23   serialized_pb=_b('\n,tensorflow/core/framework/tensor_shape.proto\x12\ntensorflow\"z\n\x10TensorShapeProto\x12-\n\x03\x64im\x18\x02 \x03(\x0b\x32 .tensorflow.TensorShapeProto.Dim\x12\x14\n\x0cunknown_rank\x18\x03 \x01(\x08\x1a!\n\x03\x44im\x12\x0c\n\x04size\x18\x01 \x01(\x03\x12\x0c\n\x04name\x18\x02 \x01(\tB\x87\x01\n\x18org.tensorflow.frameworkB\x11TensorShapeProtosP\x01ZSgithub.com/tensorflow/tensorflow/tensorflow/go/core/framework/tensor_shape_go_proto\xf8\x01\x01\x62\x06proto3')
#      24 )
#      29 _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
#      30   name='Dim',
#      31   full_name='tensorflow.TensorShapeProto.Dim',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='size', full_name='tensorflow.TensorShapeProto.Dim.size', index=0,
#      38       number=1, type=3, cpp_type=2, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#      45       number=2, type=9, cpp_type=9, label=1,
#      46       has_default_value=False, default_value=_b("").decode('utf-8'),
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50   ],
#      51   extensions=[
#      52   ],
#      53   nested_types=[],
#      54   enum_types=[
#      55   ],
#      56   serialized_options=None,
#      57   is_extendable=False,
#      58   syntax='proto3',
#      59   extension_ranges=[],
#      60   oneofs=[
#      61   ],
#      62   serialized_start=149,
#      63   serialized_end=182,
#      64 )
#      66 _TENSORSHAPEPROTO = _descriptor.Descriptor(
#      67   name='TensorShapeProto',
#      68   full_name='tensorflow.TensorShapeProto',
#    (...)
#     100   serialized_end=182,
#     101 )
#     103 _TENSORSHAPEPROTO_DIM.containing_type = _TENSORSHAPEPROTO
#
# File c:\Users\arul_\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\descriptor.py:560, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     554 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     555             default_value, message_type, enum_type, containing_type,
#     556             is_extension, extension_scope, options=None,
#     557             serialized_options=None,
#     558             has_default_value=True, containing_oneof=None, json_name=None,
#     559             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 560   _message.Message._CheckCalledFromGeneratedFile()
#     561   if is_extension:
#     562     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
